# %% [markdown]
# # How to use ipython-sql by Alejandro Beltran

# %% [markdown]
# ### Need to know the following to get started:
#
# Make sure ipython-sql is installed
# ```
# !pip install ipython-sql
# ```
# Load SQL extension using magic functions once a notebook
# ```
# %load_ext sql
# ```
# Connect to databases this way. Can connect to different ones by changing connections every time
# PostgrSQL examlpe:
# ```
# %sql postgresql://USER:PASSWORD@PATH/DATA_BASE
# ```
# github reference:
# https://github.com/catherinedevlin/ipython-sql

# %% [markdown]
# ### Different types of connections
#
# ##### Connections for SQLite, PostgreSQL, MySQL, etc databases:
# ```
# postgres://localhost:5432/postgres
# postgres://username:password@localhost:5432/postgres
# mysql://localhost/employees
# sqlite://
# sqlite:///myfile.db
#
# mysql+pymysql://scott:tiger@localhost/foo
# oracle://scott:tiger@127.0.0.1:1521/sidname
# mssql+pyodbc://username:password@host/database?driver=SQL+Server+Native+Client+11.0
# ```
# ##### Connection notes:
# ```
# Note that mysql and mysql+pymysql connections (and perhaps others) don't read your client character set information from .my.cnf. You need to specify it in the connection string:
# mysql+pymysql://scott:tiger@localhost/foo?charset=utf8
#
# Note that an impala connection with impyla for HiveServer2 requires disabling autocommit:
# %config SqlMagic.autocommit=False
# %sql impala://hserverhost:port/default?kerberos_service_name=hive&auth_mechanism=GSSAPI
# ```

# %% [markdown]
# ### Initiation

# %%
#!pip install ipython-sql

# %%
# Load SQL extension using magic functions
# %load_ext sql

# %%
# Connect to database here. Will be imported from different module 'dblogin.py' where:
    # postgresql_sql_operations_summary = postgresql://USER:PASSWORD@PATH/DATA_BASE

# Connecting to empty PostgreSQL 'sql_operations_summary' database

from dblogin import postgresql_sql_operations_summary
        
# %sql $postgresql_sql_operations_summary

# This is the same as:
# %sql postgresql://USER:PASSWORD@PATH/DATA_BASE

# %% [markdown]
# ### Options

# %% [markdown]
# List all active connections
# ```
# -l / --connections
# ```
# Close named connection
# ```
# -x / --close <session-name>
# ```
# Specify creator function for new connection
# ```
# -c / --creator <creator-function>
# ```
# Section of dsn_file to be used for generating a connection string
# ```
# -s / --section <section-name>
# ```
# Create a table name in the database from the named DataFrame
# ```
# -p / --persist
# ```
# Like --persist, but appends to the table if it already exists
# ```
# --append
# ```
# Specify dictionary of connection arguments to pass to SQL driver
# ```
# -a / --connection_arguments <"{connection arguments}">
# ```
# Run SQL from file at this path
# ```
# -f / --file <path>
# ```

# %% [markdown]
# ### Create Table in postgresql_sql_operations_summary database
# ##### Must create the database path first in PGAdmin before creating table

# %%
# %%sql
# CREATE TABLE EMPLOYEE(firstname varchar(50),lastname varchar(50));
# INSERT INTO EMPLOYEE VALUES('Tom','Mitchell');
# INSERT INTO EMPLOYEE VALUES('Jack','Ryan');
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/sql_operations_summary
# (psycopg2.errors.DuplicateTable) relation "employee" already exists
#
# [SQL: CREATE TABLE EMPLOYEE(firstname varchar(50),lastname varchar(50));]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
 # %sql SELECT * FROM EMPLOYEE;
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/sql_operations_summary
# 2 rows affected.
# [('Tom', 'Mitchell'), ('Jack', 'Ryan')]

# %% [markdown]
# ### Upload SQLite file and query

# %%
# uploading and switching to SQLite 'Studying African Farmer-led Irrigation (SAFI)' database

# %sql sqlite:///D:/Python/SQL/Data_Bases/SQL_SAFI.sqlite

# %%
# %sql SELECT * FROM Crops
# Out:
#    postgresql://postgres:***@127.0.0.1:5432/sql_operations_summary
#  * sqlite:///D:/Python/SQL/Data_Bases/SQL_SAFI.sqlite
# Done.
# [(1, 1, 1, 1, 'maize', 1),
#  (1, 2, 1, 1, 'maize', 1),
#  (2, 1, 1, 1, 'maize', 1),
#  (2, 2, 1, 1, 'tomatoes', 1),
#  (2, 3, 1, 1, 'vegetable', 1),
#  (3, 1, 1, 1, 'maize', 1),
#  (4, 1, 1, 1, 'maize', 1),
#  (4, 2, 1, 1, 'maize', 1),
#  (4, 3, 1, 1, 'sorghum', 1),
#  (5, 1, 1, 1, 'maize', 1),
#  (5, 2, 1, 1, 'maize', 1),
#  (6, 1, 1, 1, 'maize', 1),
#  (7, 1, 1, 1, 'maize', 1),
#  (7, 2, 1, 1, 'tomatoes', 1),
#  (7, 3, 1, 1, 'beans', 1),
#  (7, 4, 1, 1, 'vegetable', 1),
#  (8, 1, 1, 1, 'maize', 1),
#  (8, 2, 1, 1, 'maize', 1),
#  (9, 1, 1, 1, 'maize', 1),
#  (9, 2, 1, 1, 'tomatoes', 1),
#  (9, 3, 1, 1, 'vegetable', 1),
#  (10, 1, 1, 1, 'maize', 1),
#  (10, 2, 1, 1, 'tomatoes', 1),
#  (11, 1, 1, 1, 'maize', 1),
#  (11, 2, 1, 1, 'maize', 1),
#  (12, 1, 1, 0, 'maize', 0),
#  (12, 2, 1, 1, 'tomatoes', 1),
#  (13, 1, 1, 1, 'maize', 1),
# ...

# %%
 # %sql SELECT * FROM Crops WHERE D_curr_crop = 'maize' AND ID <= 3;
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/dvd_rentals
#    postgresql://postgres:***@127.0.0.1:5432/sql_operations_summary
# (psycopg2.errors.UndefinedTable) relation "crops" does not exist
# LINE 1: SELECT * FROM Crops WHERE D_curr_crop = 'maize' AND ID <= 3;
#                       ^
#
# [SQL: SELECT * FROM Crops WHERE D_curr_crop = 'maize' AND ID <= 3;]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %% [markdown]
# ### Using PostgreSQL commands

# %%
# Switching database to PostgreSQL 'dvd_rentals' database

from dblogin import postgresql_dvd_rentals

# %sql $postgresql_dvd_rentals

# %%
# All database schemas

# %sql \d
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/dvd_rentals
#    postgresql://postgres:***@127.0.0.1:5432/sql_operations_summary
# 35 rows affected.
# [('public', 'actor', 'table', 'postgres'),
#  ('public', 'actor_actor_id_seq', 'sequence', 'postgres'),
#  ('public', 'actor_info', 'view', 'postgres'),
#  ('public', 'address', 'table', 'postgres'),
#  ('public', 'address_address_id_seq', 'sequence', 'postgres'),
#  ('public', 'category', 'table', 'postgres'),
#  ('public', 'category_category_id_seq', 'sequence', 'postgres'),
#  ('public', 'city', 'table', 'postgres'),
#  ('public', 'city_city_id_seq', 'sequence', 'postgres'),
#  ('public', 'country', 'table', 'postgres'),
#  ('public', 'country_country_id_seq', 'sequence', 'postgres'),
#  ('public', 'customer', 'table', 'postgres'),
#  ('public', 'customer_customer_id_seq', 'sequence', 'postgres'),
#  ('public', 'customer_list', 'view', 'postgres'),
#  ('public', 'film', 'table', 'postgres'),
# ...

# %%
# All database tables

# %sql \dt
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/dvd_rentals
#    postgresql://postgres:***@127.0.0.1:5432/sql_operations_summary
# 15 rows affected.
# [('public', 'actor', 'table', 'postgres'),
#  ('public', 'address', 'table', 'postgres'),
#  ('public', 'category', 'table', 'postgres'),
#  ('public', 'city', 'table', 'postgres'),
#  ('public', 'country', 'table', 'postgres'),
#  ('public', 'customer', 'table', 'postgres'),
#  ('public', 'film', 'table', 'postgres'),
#  ('public', 'film_actor', 'table', 'postgres'),
#  ('public', 'film_category', 'table', 'postgres'),
#  ('public', 'inventory', 'table', 'postgres'),
#  ('public', 'language', 'table', 'postgres'),
#  ('public', 'payment', 'table', 'postgres'),
#  ('public', 'rental', 'table', 'postgres'),
#  ('public', 'staff', 'table', 'postgres'),
#  ('public', 'store', 'table', 'postgres')]

# %% [markdown]
# ### Different ways to query
#
# ##### Both of these ways give the same query
# ###### Method1 can only be a one-line query but the query can be printed in the same cell
# ###### Method2 can encompass any number of lines but the query must be printed in a different cell
#
# Note: When querying the value must be in '' not ""

# %% [markdown]
# ##### Method1:

# %%
result1 = %sql SELECT * FROM film  WHERE rating = 'PG-13' AND rental_rate >= 4.99;

result1
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/dvd_rentals
#    postgresql://postgres:***@127.0.0.1:5432/sql_operations_summary
# 77 rows affected.
# [(98, 'Bright Encounters', 'A Fateful Yarn of a Lumberjack And a Feminist who must Conquer a Student in A Jet Boat', 2006, 1, 4, Decimal('4.99'), 73, Decimal('12.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'boat':20 'bright':1 'conquer':14 'encount':2 'fate':4 'feminist':11 'jet':19 'lumberjack':8 'must':13 'student':16 'yarn':5"),
#  (7, 'Airplane Sierra', 'A Touching Saga of a Hunter And a Butler who must Discover a Butler in A Jet Boat', 2006, 1, 6, Decimal('4.99'), 62, Decimal('28.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'airplan':1 'boat':20 'butler':11,16 'discov':14 'hunter':8 'jet':19 'must':13 'saga':5 'sierra':2 'touch':4"),
# ...

# %% [markdown]
# ##### Method2:

# %%
# %%sql result2 <<
#
# SELECT * FROM film
# WHERE rating = 'PG-13' AND rental_rate >= 4.99;
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/dvd_rentals
#    postgresql://postgres:***@127.0.0.1:5432/sql_operations_summary
# 77 rows affected.
# Returning data to local variable result2

# %%
result2
# Out:
# [(98, 'Bright Encounters', 'A Fateful Yarn of a Lumberjack And a Feminist who must Conquer a Student in A Jet Boat', 2006, 1, 4, Decimal('4.99'), 73, Decimal('12.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'boat':20 'bright':1 'conquer':14 'encount':2 'fate':4 'feminist':11 'jet':19 'lumberjack':8 'must':13 'student':16 'yarn':5"),
#  (7, 'Airplane Sierra', 'A Touching Saga of a Hunter And a Butler who must Discover a Butler in A Jet Boat', 2006, 1, 6, Decimal('4.99'), 62, Decimal('28.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'airplan':1 'boat':20 'butler':11,16 'discov':14 'hunter':8 'jet':19 'must':13 'saga':5 'sierra':2 'touch':4"),
# ...

# %%
if result1 == result2:
    print(True)
else:
    print(False)
    
# Both queries are identical
# Out:
# True

# %% [markdown]
# ### Using Pandas and ipython-sql

# %%
import pandas as pd

# %%
# Convert query to DataFrame

expensive_pg_13_alternate = result1.DataFrame()
expensive_pg_13_alternate
# Out:
#     film_id              title  \
# 0        98  Bright Encounters
# 1         7    Airplane Sierra
# 2        28        Anthem Luke
# 3        44       Attacks Hate
# 4        45  Attraction Newton
# ..      ...                ...
# 72      944       Virgin Daisy
# 73      956      Wanda Chamber
# 74      971       Whale Bikini
# 75      972    Whisperer Giant
# 76      994      Wyoming Storm
#
#                                           description  release_year  \
# 0   A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 1   A Touching Saga of a Hunter And a Butler who m...          2006
# 2   A Touching Panorama of a Waitress And a Woman ...          2006
# 3   A Fast-Paced Panorama of a Technical Writer An...          2006
# 4   A Astounding Panorama of a Composer And a Fris...          2006
# ..                                                ...           ...
# 72  A Awe-Inspiring Documentary of a Robot And a M...          2006
# ...

# %%
expensive_pg_13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   film_id           77 non-null     int64
#  1   title             77 non-null     object
#  2   description       77 non-null     object
#  3   release_year      77 non-null     int64
#  4   language_id       77 non-null     int64
#  5   rental_duration   77 non-null     int64
#  6   rental_rate       77 non-null     object
#  7   length            77 non-null     int64
#  8   replacement_cost  77 non-null     object
#  9   rating            77 non-null     object
#  10  last_update       77 non-null     datetime64[ns]
#  11  special_features  77 non-null     object
#  12  fulltext          77 non-null     object
# dtypes: datetime64[ns](1), int64(5), object(7)
# memory usage: 7.9+ KB

# %%
expensive_pg_13.head()
# Out:
#    film_id              title  \
# 0       98  Bright Encounters
# 1        7    Airplane Sierra
# 2       28        Anthem Luke
# 3       44       Attacks Hate
# 4       45  Attraction Newton
#
#                                          description  release_year  \
# 0  A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 1  A Touching Saga of a Hunter And a Butler who m...          2006
# 2  A Touching Panorama of a Waitress And a Woman ...          2006
# 3  A Fast-Paced Panorama of a Technical Writer An...          2006
# 4  A Astounding Panorama of a Composer And a Fris...          2006
#
#    language_id  rental_duration rental_rate  length replacement_cost rating  \
# 0            1                4        4.99      73            12.99  PG-13
# 1            1                6        4.99      62            28.99  PG-13
# 2            1                5        4.99      91            16.99  PG-13
# ...

# %%
# Change database to sql_operations_summary

# %sql $postgresql_sql_operations_summary

# %%
# Save the new DataFrame from the query to a database, in this case the table is saved to a different database

# %sql --persist expensive_pg_13

# This saves the dataframe of the query expensive_pg_13 from postgresql_dvd_rentals database as a table in
    # the database postgresql_sql_operations_summary
# Out:
#    postgresql://postgres:***@127.0.0.1:5432/dvd_rentals
#  * postgresql://postgres:***@127.0.0.1:5432/sql_operations_summary
#    postgresql://postgres:***@127.0.0.1:5432/dvd_rentals
#  * postgresql://postgres:***@127.0.0.1:5432/sql_operations_summary
# 77 rows affected.
# [(0, 98, 'Bright Encounters', 'A Fateful Yarn of a Lumberjack And a Feminist who must Conquer a Student in A Jet Boat', 2006, 1, 4, '4.99', 73, '12.99', 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), '{Trailers}', "'boat':20 'bright':1 'conquer':14 'encount':2 'fate':4 'feminist':11 'jet':19 'lumberjack':8 'must':13 'student':16 'yarn':5"),
#  (1, 7, 'Airplane Sierra', 'A Touching Saga of a Hunter And a Butler who must Discover a Butler in A Jet Boat', 2006, 1, 6, '4.99', 62, '28.99', 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), '{Trailers,"Deleted Scenes"}', "'airplan':1 'boat':20 'butler':11,16 'discov':14 'hunter':8 'jet':19 'must':13 'saga':5 'sierra':2 'touch':4"),
# ...

# %%
# Check that the table is actually in the database

# %sql SELECT * FROM expensive_pg_13;
# Out:
#    postgresql://postgres:***@127.0.0.1:5432/dvd_rentals
#  * postgresql://postgres:***@127.0.0.1:5432/sql_operations_summary
# 77 rows affected.
# [(0, 98, 'Bright Encounters', 'A Fateful Yarn of a Lumberjack And a Feminist who must Conquer a Student in A Jet Boat', 2006, 1, 4, '4.99', 73, '12.99', 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), '{Trailers}', "'boat':20 'bright':1 'conquer':14 'encount':2 'fate':4 'feminist':11 'jet':19 'lumberjack':8 'must':13 'student':16 'yarn':5"),
#  (1, 7, 'Airplane Sierra', 'A Touching Saga of a Hunter And a Butler who must Discover a Butler in A Jet Boat', 2006, 1, 6, '4.99', 62, '28.99', 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), '{Trailers,"Deleted Scenes"}', "'airplan':1 'boat':20 'butler':11,16 'discov':14 'hunter':8 'jet':19 'must':13 'saga':5 'sierra':2 'touch':4"),
# ...

# %% [markdown]
# #### Can use --append to add rows to an existing table is a similar way to --persist

# %% [markdown]
# ### matplotlib and ipython-sql

# %%
# %matplotlib inline
# from matplotlib.pyplot import pie

# %%
result =  %sql SELECT title, rental_duration FROM expensive_pg_13 WHERE replacement_cost > '29'
result.pie()
# Out:
#    postgresql://postgres:***@127.0.0.1:5432/dvd_rentals
#  * postgresql://postgres:***@127.0.0.1:5432/sql_operations_summary
# 8 rows affected.
# ([<matplotlib.patches.Wedge at 0x2362e8574f0>,
# ...
#  [Text(1.0162674857624154, 0.4209517756015988, 'Blindness Gun'),
#   Text(0.42095177560159885, 1.0162674857624154, 'Jingle Sagebrush'),
#   Text(-0.42095177560159874, 1.0162674857624154, 'Matrix Snowman'),
#   Text(-1.0162674857624154, 0.4209517756015989, 'Poseidon Forever'),
#   Text(-0.9865600232778008, -0.48651754384616536, 'Right Cranes'),
#   Text(-0.35358345246839334, -1.0416231286509203, 'Thin Sagebrush'),
#   Text(0.4209517280266836, -1.0162675054685892, 'Virgin Daisy'),
#   Text(1.0162674660562394, -0.42095182317651303, 'Wyoming Storm')])

# %% [markdown]
# ### Dumping

# %%
result = %sql SELECT title, totalwords FROM work WHERE genretype = 'c'

result.csv(filename='work.csv')

# %% [markdown]
# ### Configuration

# %% [markdown]
# Query results are loaded as lists, so very large result sets may use up your system's memory and/or hang your browser. There is no autolimit by default. However, autolimit (if set) limits the size of the result set (usually with a LIMIT clause in the SQL). displaylimit is similar, but the entire result set is still pulled into memory (for later analysis); only the screen display is truncated.

# %%
# Shows current configurations
# %config SqlMagic
# Out:
# SqlMagic(Magics, Configurable) options
# ------------------------------------
# SqlMagic.autocommit=<Bool>
#     Set autocommit mode
#     Current: True
# SqlMagic.autolimit=<Int>
#     Automatically limit the size of the returned result sets
#     Current: 0
# SqlMagic.autopandas=<Bool>
#     Return Pandas DataFrames instead of regular result sets
#     Current: False
# SqlMagic.column_local_vars=<Bool>
#     Return data into local variables from column names
#     Current: False
# SqlMagic.displaycon=<Bool>
#     Show connection string after execute
#     Current: True
# SqlMagic.displaylimit=<Int>
#     Automatically limit the number of rows displayed (full result set is still
#     stored)
#     Current: None
# SqlMagic.dsn_filename=<Unicode>
#     Path to DSN file. When the first argument is of the form [section], a
#     sqlalchemy connection string is formed from the matching section in the DSN
#     file.
#     Current: 'odbc.ini'
# SqlMagic.feedback=<Bool>
# ...

# %% [markdown]
# ##### Change configurations example:
# ```
# %config SqlMagic.feedback = False
# ```
