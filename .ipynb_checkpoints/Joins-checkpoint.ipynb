# %% [markdown]
# # SQL Series: Query using JOINs
# # by Alejandro Beltran

# %% [markdown]
# ### Initiation

# %%
# Load SQL extension using magic functions
# %load_ext sql

# %% [markdown]
# ## Table Joins
# ## Material in this sheet:
#
# <br>
#
# ### Joining tables using JOIN
#
#
# <br>

# %% [markdown]
# ### Using Joins:
#     One should use joins when quering info from more than one table. When creating information one should plan before making the database tables. The planning of the tables are done through an Entity Relationship Diagram (ERD). Where tables should contain different information but should be able to be related to each other.
#
# <br>
#
#     The following two tables, owners and pets, have information on owners of pets and pets themselves. Both tables contain different sets of information. Since an owner can have one or more pets and a pet can have one or more owners, it is smart to group both sets of information in different tables. The tables are related in this case by Pet_ID.

# %% [markdown]
# ![Table_joins.png](attachment:Table_joins.png)

# %% [markdown]
# ##### To query the name of the owners and the pet name, JOIN must be used. There are different ways to join information as seen in the following image:

# %% [markdown]
# ![Visual_SQL_JOINS.jpg](attachment:Visual_SQL_JOINS.jpg)

# %% [markdown]
# ##### To query the previous example an inner join can be used:

# %% [markdown]
# ![join_example.png](attachment:join_example.png)

# %% [markdown]
# ### The following examples will go further into different types of joins

# %%
# Connect to database here.
from dblogin import postgresql_sql_operations_summary, postgresql_dvd_rentals
        
# %sql $postgresql_sql_operations_summary 
# %sql $postgresql_dvd_rentals

# %%
# %%sql result <<
# Out:
# UsageError: Cell magic `%%sql` not found.

# %%
#

result
